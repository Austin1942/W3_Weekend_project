# %%
#I had a tough time understand where to even start with biulding this game so i looked up a step by step tutoial to help me
# build this game it is located here --> https://samarakoon-gayan.medium.com/a-game-of-black-jack-on-python-as-a-fun-exercise-3cd54efb9d83
# let me know if this ok or if I did the wrong thing here,  thank you 


import random

suits = ('Mountain', 'Forest', 'Plains', 'Swamp')
stats = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Lieutenant', 'Captain', 'Plains Walker', 'Land')
values = {'Two': 2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Lieutenant':10, 'Captain':10, 'Plains Walker':10, 'Land':11}

playing = True


class Card:

    def __init__(self, suit, stat):
        self.suit = suit
        self.stat = stat

    def __str__(self):
        return self.stat + ' of ' + self.suit


class Deck:

    def __init__ (self):
        self.deck = []
        for suit in suits:
            for stat in stats:
                self.deck.append(Card(suit,stat))

    def __str__(self):
        deck_comp = ''
        for card in self.deck:
            deck_comp += '\n '+ card.__str__()
        return 'The deck has:' + deck_comp

    def shuffle(self):
        random.shuffle(self.deck)

    def deal(self):
        single_card = self.deck.pop()
        return single_card

    
class Hand:
    
    def __init__(self):
        self.cards = []
        self.value = 0
        self.lands = 0

    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.stat]
        if card.stat == 'Land':
            self.lands += 1

    def adjust_for_land(self):
        pass
        while self.value > 21 and self.lands:
            self.value -= 10
            self.lands -= 1

    
class Tokens:

    def __init__(self):
        self.total = 100
        self.bet = 0


    def win_bet(self):
        self.total += self.bet

    def lose_bet(self):
        self.total -= self.bet
        
def take_bet(tokens):
    
    while True:
        try:
            tokens.bet = int(input('How many Tokens would you like to use? '))
        except ValueError:
            print('Sorry, but Tokens are only numbered (integers).')
        else:
            if tokens.bet > tokens.total:
                print('Sorry, you can not exceed your total Tokens', tokens.total)
            else:
                break
                
def hit(self,hand):
    
    hand.add_card(deck.deal())
    hand.adjust_for_land()
    

def hit_or_stand(deck,hand):
    global playing
    
    while True:
        x = input("Would you like to Attack or Stand you ground? Type A or S ")
        
        if x[0].lower() == 'a':
            hit(deck,hand)
        elif x[0].lower() == 's':
            print("The Player Stands there ground. Dealer's turn to Strike.")
            playing = False
        else:
            print("Not Valid... TRY AGAIN!!")
            continue
        break

        
def show_start(player, dealer):
    print("\nDealer's Hand:")
    print(" <card hidden>")
    print('', dealer.cards[1])
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    
def show_all(player,dealer):
    print("\nDealer's Hand:", *player.cards, sep='\n ')
    print("Dealer's Hand =", dealer.value)
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    print("Player's Hand =",player.value)
    

    
def player_looses(player,dealer,chips):
    print("Player! You have FAILED!")
    chips.loser_bet()
    
def player_wins(player,dealer,chips):
    print("Player! You are VICTORIOUS!!")
    chips.win_bet()
    
def dealer_looses(player,dealer,chips):
    print("The Dealer has FAILED!")
    chips.win_bet()
    
def dealer_wins(player,dealer,chips):
    print("The Dealer has out witted you!")
    chips.loser_bet()
    
def tie(player,dealer):
    print("You are equil to your Foe in stength and skill!")
    
    
while True:
    print('\n\
    Welcome to MTG Battle Blackjack!! The rules are....\n\
    Get as close to 21 as you can\n\
    The Dealer will Strike until they reach 17. \n\
    Card key: lands = 1 or 11, Lieutenant = 10, Captain = 10, Plains Walker = 10')
    
    deck = Deck()
    deck.shuffle()
    
    player_hand = Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
    
    player_tokens = Tokens()
    
    take_bet(player_tokens)
    
    show_start(player_hand, dealer_hand)
    
    while playing:
        hit_or_stand(deck,player_hand)
        show_start(player_hand, dealer_hand)
        
        if player_hand.value > 21:
            player_busts(player_hand, dealer_hand,player_tokens)
            break
            
            
    if player_hand.value <= 21:
        while dealer_hand.value < 17:
            hit(deck, dealer_hand)
            
        show_all(player_hand,dealer_hand)
        
        if dealer_hand.value > 21:
            dealer_looses(player_hand, dealer_hand, player_tokens)
        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand, dealer_hand, player_tokens)
        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand, dealer_hand, player_tokens)
        else:
            tie(player_hand, dealer_hand)
            
    print("\n Player! Your Bounty stands at: ", player_tokens.total)
    new_game = input("Would you like to test your steel agian Player? Enter 'Y' or 'N'")
    
    if new_game[0].lower() == 'y':
        player = True
        continue
    else:
        print("You fought bravely today!")
        break
# Out:
#     Welcome to MTG Battle Blackjack!! The rules are....
#     Get as close to 21 as you can
#     The Dealer will Strike until they reach 17.
#     Card key: lands = 1 or 11, Lieutenant = 10, Captain = 10, Plains Walker = 10
# How many Tokens would you like to use? 100
#
# Dealer's Hand:
#  <card hidden>
#  Eight of Forest
#
# Player's Hand:
#  Three of Forest
#  Six of Plains
# Would you like to Attack or Stand you ground? Type A or S a
#
# Dealer's Hand:
#  <card hidden>
#  Eight of Forest
#
# Player's Hand:
#  Three of Forest
#  Six of Plains
#  Captain of Plains
# Would you like to Attack or Stand you ground? Type A or S s
# The Player Stands there ground. Dealer's turn to Strike.
#
# Dealer's Hand:
#  <card hidden>
#  Eight of Forest
#
# Player's Hand:
#  Three of Forest
#  Six of Plains
#  Captain of Plains
#
# Dealer's Hand:
#  Three of Forest
#  Six of Plains
#  Captain of Plains
# Dealer's Hand = 24
#
# Player's Hand:
#  Three of Forest
#  Six of Plains
#  Captain of Plains
# ...
